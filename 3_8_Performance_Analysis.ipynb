# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
r2 = {'rdkit': 0.6236718457498858, 'cfps': 0.6099911506622377, 'bitfps': 0.5943336105746906, 
      'mordred': 0.6095690657258918, 'mordred_3D': 0.4531217029586032}
mae = {'rdkit': 0.3451506062914753, 'cfps': 0.3605353407145101, 'bitfps': 0.3768983465920342, 
       'mordred': 0.3623127634728058, 'mordred_3D': 0.45644754463506515}
mse = {'rdkit': 0.24302451426881816, 'cfps': 0.25185920877941215, 'bitfps': 0.2619705066758,
       'mordred': 0.25152145422485783, 'mordred_3D': 0.3523071879834592}

# %%
names = ['rdkit', 'cfps', 'bitfps', 'mordred', 'mordred_3D']
colour = ['red', 'blue', 'green', 'orange', 'purple']
for i, n in enumerate(names):
    plt.bar(n, r2[n], color=colour[i])
plt.ylabel('R2')
plt.title('R2 Performance for Combined Dataset')
plt.show()

# %%
names = ['rdkit', 'cfps', 'bitfps', 'mordred', 'mordred_3D']
colour = ['red', 'blue', 'green', 'orange', 'purple']
for i, n in enumerate(names):
    plt.bar(n, mae[n], color=colour[i])
plt.ylabel('MAE')
plt.title('MAE Performance for Combined Dataset')
plt.show()

# %%
names = ['rdkit', 'cfps', 'bitfps', 'mordred', 'mordred_3D']
colour = ['red', 'blue', 'green', 'orange', 'purple']
for i, n in enumerate(names):
    plt.bar(n, mse[n], color=colour[i])
plt.ylabel('MSE')
plt.title('MSE Performance for Combined Dataset')
plt.show()

# %%
r2_wc = {'rdkit': 0.7451168723510939,
        'cfps': 0.7514134062257889,
        'bitfps': 0.7080582415145305,
        'mordred': 0.7701035352023142,
        'mordred_3D': 0.654758960148139}
mae_wc = {'rdkit': 0.30100466579689816,
        'cfps': 0.2949458477588922,
        'bitfps': 0.3104617337755391,
        'mordred': 0.2850745800007431,
        'mordred_3D':0.3549506897453651}
mse_wc = {'rdkit': 0.15540550402167796,
         'cfps': 0.1515664267574723,
         'bitfps': 0.17800062538821446,
         'mordred': 0.14058305879447947,
         'mordred_3D': 0.2111169540883258}

# %%
names = ['rdkit', 'cfps', 'bitfps', 'mordred', 'mordred_3D']
colour = ['red', 'blue', 'green', 'orange', 'purple']
for i, n in enumerate(names):
    plt.bar(n, r2_wc[n], color=colour[i])
plt.ylabel('R2')
plt.title('R2 Performance for Wang & Chen 2020 Dataset')
plt.show()

# %%
names = ['rdkit', 'cfps', 'bitfps', 'mordred', 'mordred_3D']
colour = ['red', 'blue', 'green', 'orange', 'purple']
for i, n in enumerate(names):
    plt.bar(n, mae_wc[n], color=colour[i])
plt.ylabel('MAE')
plt.title('MAE Performance for Wang & Chen 2020 Dataset')
plt.show()

# %%
names = ['rdkit', 'cfps', 'bitfps', 'mordred', 'mordred_3D']
colour = ['red', 'blue', 'green', 'orange', 'purple']
for i, n in enumerate(names):
    plt.bar(n, mse_wc[n], color=colour[i])
plt.ylabel('MSE')
plt.title('MSE Performance for Wang & Chen 2020 Dataset')
plt.show()

# %%
plt.bar('rdkit', r2['rdkit'], color='#1f77b4')
plt.bar('mordred_wc', r2_wc['mordred'], color='orange')
plt.show()

# %%
bar_width = 1
x = pd.Series([i for i in range(1,4)])
y_combined = [0.6236718457498858, 0.3451506062914753, 0.24302451426881816]
y_wc = [0.7701035352023142, 0.2850745800007431, 0.14058305879447947]
plt.bar(x - (bar_width/3)/2, y_combined, align='center', width=bar_width/3, alpha=0.5)
plt.bar(x + (bar_width/3)/2, y_wc, align='center', width=bar_width/3, alpha=0.5)
plt.legend(['Combined Dataset', 'Wang & Chen 2020'], loc='upper right')
plt.ylabel('Scores')
plt.title('Performance of LightGBM with best performing descriptors: Combined vs Wang&Chen2020')
plt.xticks([i for i in range(1,4)], ['R2', 'MAE', 'MSE'])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 bar_width = 1
# ----> 2 x = pd.Series([i for i in range(1,4)])
#       3 y_combined = [0.6236718457498858, 0.3451506062914753, 0.24302451426881816]
#       4 y_wc = [0.7701035352023142, 0.2850745800007431, 0.14058305879447947]
#
# NameError: name 'pd' is not defined
